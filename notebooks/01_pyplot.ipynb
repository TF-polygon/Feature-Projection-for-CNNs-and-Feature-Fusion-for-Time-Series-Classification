# %%
import matplotlib.pyplot as plt
import pandas as pd

train_df = pd.read_csv('C:/Users/CVPR Lab/Desktop/METAVERSE LAB/[LAB]Research/[2025-12]Multi Feature Fusion/data/results/01-06_11-32_train.csv')
valid_df = pd.read_csv('C:/Users/CVPR Lab/Desktop/METAVERSE LAB/[LAB]Research/[2025-12]Multi Feature Fusion/data/results/01-06_11-32_valid.csv')

# %%
train_acc = train_df['Train Accuracy']
train_loss = train_df['Train Loss']

valid_acc = valid_df['Val Accuracy']
valid_loss = valid_df['Val Loss']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Train')
plt.plot(valid_acc, label='Valid')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Train')
plt.plot(valid_loss, label='Valid')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='best')
